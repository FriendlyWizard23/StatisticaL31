# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as st

# %% [markdown]
# Manca il dataset quindi faccio solo ES2

# %%
dist=st.geom(4/10)
x=np.arange(1,30,1)
plt.step(x,dist.cdf(x))
plt.show()
