# %%
import scipy.stats as st
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x = np.arange(0, 15, 1)
rv = st.randint(2, 15)
plt.vlines(x, 0, rv.cdf(x), colors='b')
plt.show()
rv.pmf(2)
# Out:
# 0.07692307692307693
